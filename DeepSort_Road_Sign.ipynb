# %% [markdown]
# <a href="https://colab.research.google.com/github/Rupesh-Kataria/Road_Sign_Detection/blob/main/DeepSort_Road_Sign.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !ln -s /content/gdrive/My\ Drive/ /mydrive

# %%
# %cd /mydrive/DeepSort_traffic_sign_detection
# Out:
# /content/gdrive/My Drive/DeepSort_traffic_sign_detection

# %%
# clone repository for deepsort with yolov4
# !git clone https://github.com/theAIGuysCode/yolov4-deepsort
# Out:
# Cloning into 'yolov4-deepsort'...
# remote: Enumerating objects: 143, done.
# remote: Total 143 (delta 0), reused 0 (delta 0), pack-reused 143
# Receiving objects: 100% (143/143), 76.84 MiB | 15.34 MiB/s, done.
# Resolving deltas: 100% (41/41), done.
# Updating files: 100% (62/62), done.

# %%
# %cd /mydrive/DeepSort_traffic_sign_detection/yolov4-deepsort
# Out:
# /content/gdrive/My Drive/DeepSort_traffic_sign_detection/yolov4-deepsort

# %%
# Convert darknet weights to tensorflow model

# !python save_model.py --model yolov4
# Out:
# 2023-06-23 10:37:41.776556: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-06-23 10:37:43.184514: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_1 (InputLayer)           [(None, 416, 416, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 416, 416, 32  864         ['input_1[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 416, 416, 32  128        ['conv2d[0][0]']
#  alization)                     )
#
# ...

# %%
# run DeepSort with YOLOv4 Object Detections as backbone (enable --info flag to see info about tracked objects)
# !python object_tracker.py --video ./data/video/road_sign.mp4 --output ./outputs/road_sign.avi --model yolov4 --dont_show
# Out:
# Frame #:  1
# FPS: 0.27
# Frame #:  2
# FPS: 0.55
# Frame #:  3
# FPS: 0.41
# Frame #:  4
# FPS: 0.22
# Frame #:  5
# FPS: 0.53
# Frame #:  6
# FPS: 0.56
# Frame #:  7
# FPS: 0.56
# Frame #:  8
# FPS: 0.55
# Frame #:  9
# FPS: 0.54
# Frame #:  10
# FPS: 0.41
# Frame #:  11
# FPS: 0.31
# Frame #:  12
# FPS: 0.53
# Frame #:  13
# FPS: 0.57
# Frame #:  14
# FPS: 0.56
# Frame #:  15
# FPS: 0.56
# Frame #:  16
# FPS: 0.56
# Frame #:  17
# FPS: 0.47
# Frame #:  18
# FPS: 0.30
# Frame #:  19
# FPS: 0.45
# Frame #:  20
# FPS: 0.53
# Frame #:  21
# FPS: 0.56
# Frame #:  22
# FPS: 0.54
# Frame #:  23
# FPS: 0.57
# Frame #:  24
# FPS: 0.49
# Frame #:  25
# FPS: 0.30
# Frame #:  26
# FPS: 0.44
# Frame #:  27
# FPS: 0.56
# Frame #:  28
# FPS: 0.56
# Frame #:  29
# FPS: 0.56
# Frame #:  30
# FPS: 0.56
# Frame #:  31
# FPS: 0.55
# Frame #:  32
# FPS: 0.31
# Frame #:  33
# FPS: 0.39
# Frame #:  34
# FPS: 0.56
# Frame #:  35
# FPS: 0.55
# Frame #:  36
# FPS: 0.54
# Frame #:  37
# FPS: 0.54
# ...
